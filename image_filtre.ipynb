# %% [markdown]
# <a href="https://colab.research.google.com/github/ym001/ISNTS/blob/master/image_filtre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image               # to load images
from IPython.display import display # to display images
import os
from google.colab import drive
drive.mount('/content/gdrive')
print(os.listdir('./gdrive/My Drive/'))
print(os.getcwd())
img = Image.open("./gdrive/My Drive/image1.png")
display(img)
largeur=img.size[0]
hauteur=img.size[1]
for x in range(largeur):    # pour tous les pixels
  for y in range(hauteur):
    rouge,vert,bleu,i=img.getpixel((x,y))
    img.putpixel((x, y), (rouge,0,0))
display(img)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ['Colab Notebooks', 'ecole_yves', 'image1.png']
# /content
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=272x92 at 0x7F181B939C50>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=272x92 at 0x7F181B939C50>
